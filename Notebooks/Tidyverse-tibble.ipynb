# %%
Neste notebook descrevemos o conjunto de bibliotecas exploratorias do R conhecidos como tidyverse

Estes serão:

ggplot2
tibble
tidyr
readr
purrr
dplyr
stringr
forcats

Neste notebook discutimos o tibble

# %% [markdown]
# O tibble é um pacote que introduz uma nova estrutura ao R que traz todas as vantagens do data.frame sem incorporar algumas das features deste que entraram em desuso com o passar do tempo, comecemos carregando o dataset do kickstarter

# %%
require(tidyverse)
# Out:
# Loading required package: tidyverse
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.1.0     ✔ purrr   0.2.5
# ✔ tibble  2.0.1     ✔ dplyr   0.7.6
# ✔ tidyr   0.8.1     ✔ stringr 1.4.0
# ✔ readr   1.1.1     ✔ forcats 0.3.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
Kick=read.csv("Kickstarter.csv")

# %%
head(Kick)
# Out:
#   backers_count
# 1  80
# 2  31
# 3 357
# 4  74
# 5  12
# 6 667
#   blurb
# 1 If you've ever been disheartened by how some people might represent the character of Christ, this is the book for you.
# 2 This book will show you how to attract your ideal client and get them to buy from you again and again without ever selling.
# 3 Our goal is to re-publish 500 old Christian books. Available to read online, to download, or as physical books. Help us make it!
# 4 I told my first lie when I was six and never stopped. A how-to book on lying. I even lied to my parents on what it was about.
# 5 Für die Finanzierung der Veröffentlichung meiner Masterarbeit, die dann als eigenständiges Buch bei Turia&Kant erscheint.
# 6 The third in the landmark series detailing the making of the original Star Trek TV Series.
#   category
# ...

# %%
class(Kick)
# Out:
# [1] "data.frame"

# %%
KickTibble=as_tibble(Kick)

# %%
KickTibble
# Out:
#      backers_count
# 1     80
# 2     31
# 3    357
# 4     74
# 5     12
# 6    667
# 7     44
# 8     30
# 9     86
# 10   546
# 11    76
# 12    57
# 13   549
# 14    31
# 15   157
# 16    80
# 17    53
# 18   159
# 19   111
# 20   578
# 21   207
# 22    48
# 23    94
# 24   220
# 25    46
# 26    36
# 27    95
# 28   189
# 29     3
# 30    88
# ⋮    ⋮
# 3979  306
# 3980    9
# 3981  204
# 3982  663
# 3983  351
# 3984    7
# 3985   14
# 3986   28
# 3987 1570
# 3988    3
# 3989    1
# 3990  429
# 3991    7
# 3992   46
# 3993   27
# 3994  105
# 3995   16
# 3996  585
# 3997    7
# 3998   13
# 3999  885
# 4000   41
# 4001    6
# 4002    7
# 4003  959
# 4004   25
# 4005    9
# 4006  105
# 4007    7
# 4008  149
#      blurb
# 1    If you've ever been disheartened by how some people might represent the character of Christ, this is the book for you.
# 2    This book will show you how to attract your ideal client and get them to buy from you again and again without ever selling.
# ...

# %%
class(KickTibble)
# Out:
# [1] "tbl_df"     "tbl"        "data.frame"

# %% [markdown]
# Como a estrutura de tibble podemos comparar as duas estruturas para justificar o porque desta
